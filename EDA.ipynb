# %%
import pandas as pd

# %%
from Libraries_vancouver_weather import v2013_df1

# %%
v2013_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2013      1    1           NaN            NaN  ...             NaN
# 1    2013      1    2           NaN            NaN  ...             NaN
# 2    2013      1    3           NaN            NaN  ...             NaN
# 3    2013      1    4           NaN            NaN  ...             NaN
# 4    2013      1    5           NaN            NaN  ...             NaN
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2013     12   27           NaN            NaN  ...             NaN
# 361  2013     12   28           NaN            6.8  ...             0.0
# 362  2013     12   29           NaN            5.8  ...             0.0
# 363  2013     12   30           NaN            7.0  ...             0.0
# 364  2013     12   31           NaN            7.4  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               NaN                NaN               NaN
# 1                NaN               NaN                NaN               NaN
# 2                NaN               NaN                NaN               NaN
# 3                NaN               NaN                NaN               NaN
# 4                NaN               NaN                NaN               NaN
# ..               ...               ...                ...               ...
# 360              NaN               NaN                  M               0.0
# 361              NaN               0.0                NaN               NaN
# 362              NaN               1.2                NaN               NaN
# 363              NaN               0.0                  T               NaN
# 364              NaN               2.2                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                       NaN                   NaN
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                       NaN                     M
# 361                NaN                       NaN                   NaN
# 362                NaN                       NaN                   NaN
# 363                NaN                       NaN                   NaN
# 364                NaN                       NaN                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ..                     ...                   ...
# 360                    NaN                     M
# 361                    <31                   NaN
# 362                    <31                   NaN
# 363                    <31                   NaN
# 364                    <31                   NaN
#
# [365 rows x 31 columns]

# %%
v2013_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2013_P1D.csv")

# %%
v2014_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2014_P1D.csv")

# %%
v2014_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2014      1    1           NaN            6.5  ...             0.0
# 1    2014      1    2           NaN            7.5  ...             0.0
# 2    2014      1    3           NaN            6.8  ...             0.0
# 3    2014      1    4           NaN            4.9  ...             0.0
# 4    2014      1    5           NaN            4.7  ...             0.0
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2014     12   27           NaN            6.5  ...             0.0
# 361  2014     12   28           NaN            4.8  ...             0.0
# 362  2014     12   29           NaN            5.7  ...             0.0
# 363  2014     12   30           NaN            1.6  ...             0.0
# 364  2014     12   31           NaN            2.1  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.8                NaN               NaN
# 1                NaN              13.8                NaN               NaN
# 2                NaN               0.0                NaN               NaN
# 3                NaN               0.0                NaN               NaN
# 4                NaN               0.0                NaN               NaN
# ..               ...               ...                ...               ...
# 360              NaN              11.0                NaN               0.0
# 361              NaN               0.0                  T               0.0
# 362              NaN               0.0                NaN               0.0
# 363              NaN               0.0                NaN               0.0
# 364              NaN               0.0                NaN               0.0
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                       NaN                   NaN
# 1                  NaN                      28.0                   NaN
# 2                  NaN                      28.0                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                      28.0                   NaN
# 361                NaN                      30.0                   NaN
# 362                NaN                       7.0                   NaN
# 363                NaN                       8.0                   NaN
# 364                NaN                       NaN                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                      <31                   NaN
# 1                       80                   NaN
# 2                       76                   NaN
# 3                      <31                   NaN
# 4                      <31                   NaN
# ..                     ...                   ...
# 360                     54                   NaN
# 361                     33                   NaN
# 362                     33                   NaN
# 363                     37                   NaN
# 364                    <31                   NaN
#
# [365 rows x 31 columns]

# %%
v2015_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2015_P1D.csv")

# %%
v2015_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2015-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2015-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2015-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2015-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2015-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2015-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2015-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2015-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2015-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2015-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2015      1    1           NaN            3.4  ...             0.0
# 1    2015      1    2           NaN            3.6  ...             0.0
# 2    2015      1    3           NaN            3.8  ...             0.0
# 3    2015      1    4           NaN            6.5  ...             0.0
# 4    2015      1    5           NaN            9.2  ...             0.0
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2015     12   27           NaN            5.4  ...             0.0
# 361  2015     12   28           NaN            4.6  ...             0.0
# 362  2015     12   29           NaN            5.6  ...             0.0
# 363  2015     12   30           NaN            2.6  ...             0.0
# 364  2015     12   31           NaN            2.7  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.0                NaN               0.0
# 1                NaN               3.8                NaN               0.0
# 2                NaN               2.8                NaN               0.0
# 3                NaN              38.0                NaN               0.0
# 4                NaN              20.0                NaN               0.0
# ..               ...               ...                ...               ...
# 360              NaN              13.0                NaN               0.0
# 361              NaN               0.4                NaN               0.0
# 362              NaN               0.0                NaN               0.0
# 363              NaN               0.0                NaN               0.0
# 364              NaN               0.0                NaN               0.0
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                       NaN                   NaN
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       5.0                   NaN
# 4                  NaN                      30.0                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                      11.0                   NaN
# 361                NaN                       NaN                   NaN
# 362                NaN                       NaN                   NaN
# 363                NaN                       NaN                   NaN
# 364                NaN                       NaN                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                      <31                   NaN
# 1                      <31                   NaN
# 2                      <31                   NaN
# 3                       43                   NaN
# 4                       33                   NaN
# ..                     ...                   ...
# 360                     48                   NaN
# 361                    <31                   NaN
# 362                    <31                   NaN
# 363                    <31                   NaN
# 364                    <31                   NaN
#
# [365 rows x 31 columns]

# %%
v2016_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2016_P1D.csv")

# %%
v2017_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2017_P1D.csv")

# %%
v2018_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2018_P1D.csv")

# %%
v2019_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2019_P1D.csv")

# %%
v2020_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2020_P1D.csv")

# %%
v2021_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2021_P1D.csv")

# %%
v2022_df1 = pd.read_csv(r"C:\Users\Tombra\Vancouver_Weather_Predictions\Vancouver_raw_data\en_climate_daily_BC_1108395_2022_P1D.csv")

# %%
v2018_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2018-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2018-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2018-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2018-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2018-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2018-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2018-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2018-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2018-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2018-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2018      1    1           NaN            3.0  ...             0.0
# 1    2018      1    2           NaN            3.0  ...             0.0
# 2    2018      1    3           NaN            4.0  ...             0.0
# 3    2018      1    4           NaN            5.7  ...             0.0
# 4    2018      1    5           NaN            9.7  ...             0.0
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2018     12   27           NaN            5.5  ...             0.0
# 361  2018     12   28           NaN            4.8  ...             0.0
# 362  2018     12   29           NaN           10.6  ...             0.0
# 363  2018     12   30           NaN            7.8  ...             0.0
# 364  2018     12   31           NaN            5.2  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.0                NaN               NaN
# 1                NaN               0.0                NaN               NaN
# 2                NaN               0.0                NaN               NaN
# 3                NaN               0.0                  T               NaN
# 4                NaN              21.8                NaN               NaN
# ..               ...               ...                ...               ...
# 360              NaN               0.0                  T               NaN
# 361              NaN              35.6                NaN               NaN
# 362              NaN              10.0                NaN               NaN
# 363              NaN               0.0                  T               NaN
# 364              NaN               0.0                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                       NaN                   NaN
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                       NaN                     M
# 361                NaN                       NaN                   NaN
# 362                NaN                      18.0                   NaN
# 363                NaN                      29.0                   NaN
# 364                NaN                       NaN                     M
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                      <31                   NaN
# 1                      <31                   NaN
# 2                      <31                   NaN
# 3                      <31                   NaN
# 4                      <31                   NaN
# ..                     ...                   ...
# 360                    NaN                     M
# 361                    NaN                     M
# 362                     58                   NaN
# 363                     67                   NaN
# 364                    NaN                     M
#
# [365 rows x 31 columns]

# %%
v2018_df1.describe()
# Out:
#        Longitude (x)  Latitude (y)  Climate ID    Year       Month  \
# count   3.650000e+02  3.650000e+02       365.0   365.0  365.000000
# mean   -1.231800e+02  4.919000e+01   1108395.0  2018.0    6.526027
# std     2.419161e-13  3.557590e-14         0.0     0.0    3.452584
# min    -1.231800e+02  4.919000e+01   1108395.0  2018.0    1.000000
# 25%    -1.231800e+02  4.919000e+01   1108395.0  2018.0    4.000000
# 50%    -1.231800e+02  4.919000e+01   1108395.0  2018.0    7.000000
# 75%    -1.231800e+02  4.919000e+01   1108395.0  2018.0   10.000000
# max    -1.231800e+02  4.919000e+01   1108395.0  2018.0   12.000000
#
#               Day  Data Quality  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# count  365.000000           0.0     365.000000     364.000000      364.000000
# mean    15.720548           NaN      14.383836       7.177747       10.796429
# std      8.808321           NaN       6.492463       5.377791        5.791388
# min      1.000000           NaN      -1.100000      -7.500000       -3.400000
# 25%      8.000000           NaN       9.100000       3.000000        6.300000
# 50%     16.000000           NaN      13.800000       7.100000       10.150000
# 75%     23.000000           NaN      19.700000      11.900000       15.900000
# max     31.000000           NaN      29.000000      17.200000       22.700000
#
#        Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# count          364.000000          364.000000        363.00000
# mean             7.438736            0.235165          3.65124
# std              5.423808            0.783701          7.56686
# min              0.000000            0.000000          0.00000
# 25%              2.100000            0.000000          0.00000
# 50%              7.850000            0.000000          0.00000
# 75%             11.700000            0.000000          3.80000
# max             21.400000            4.700000         67.00000
#
#        Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)  \
# count       364.000000         364.000000          11.000000
# mean          0.070879           3.690659           3.727273
# std           0.722353           7.566930           4.797727
# min           0.000000           0.000000           0.000000
# 25%           0.000000           0.000000           1.000000
# 50%           0.000000           0.000000           2.000000
# 75%           0.000000           4.050000           3.500000
# max          11.000000          67.000000          15.000000
#
#        Dir of Max Gust (10s deg)
# count                 236.000000
# mean                   18.775424
# std                     7.784080
# min                     3.000000
# 25%                    12.000000
# 50%                    19.000000
# 75%                    27.000000
# max                    33.000000

# %%
v2018_df1.dtypes
# Out:
# Longitude (x)                float64
# Latitude (y)                 float64
# Station Name                  object
# Climate ID                     int64
# Date/Time                     object
# Year                           int64
# Month                          int64
# Day                            int64
# Data Quality                 float64
# Max Temp (°C)                float64
# Max Temp Flag                 object
# Min Temp (°C)                float64
# Min Temp Flag                 object
# Mean Temp (°C)               float64
# Mean Temp Flag                object
# Heat Deg Days (°C)           float64
# Heat Deg Days Flag            object
# Cool Deg Days (°C)           float64
# Cool Deg Days Flag            object
# Total Rain (mm)              float64
# Total Rain Flag               object
# Total Snow (cm)              float64
# Total Snow Flag               object
# Total Precip (mm)            float64
# Total Precip Flag             object
# Snow on Grnd (cm)            float64
# Snow on Grnd Flag             object
# Dir of Max Gust (10s deg)    float64
# Dir of Max Gust Flag          object
# Spd of Max Gust (km/h)        object
# Spd of Max Gust Flag          object
# dtype: object

# %%
v2020_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2020-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2020-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2020-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2020-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2020-01-05
# ..             ...           ...               ...         ...         ...
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2020-12-27
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2020-12-28
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2020-12-29
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2020-12-30
# 365        -123.18         49.19  VANCOUVER INTL A     1108395  2020-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2020      1    1           NaN           10.7  ...             0.0
# 1    2020      1    2           NaN            6.3  ...             0.0
# 2    2020      1    3           NaN           12.0  ...             0.0
# 3    2020      1    4           NaN            8.4  ...             0.0
# 4    2020      1    5           NaN            8.3  ...             0.0
# ..    ...    ...  ...           ...            ...  ...             ...
# 361  2020     12   27           NaN            6.6  ...             0.0
# 362  2020     12   28           NaN            6.7  ...             0.0
# 363  2020     12   29           NaN            5.6  ...             0.0
# 364  2020     12   30           NaN            6.1  ...             0.0
# 365  2020     12   31           NaN            7.6  ...             0.0
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.8                NaN               NaN
# 1                NaN               8.0                NaN               NaN
# 2                NaN              16.2                NaN               NaN
# 3                NaN               2.8                NaN               NaN
# 4                NaN               0.8                NaN               NaN
# ..               ...               ...                ...               ...
# 361              NaN               6.4                NaN               NaN
# 362              NaN               0.8                NaN               NaN
# 363              NaN               8.2                NaN               NaN
# 364              NaN              31.6                NaN               NaN
# 365              NaN               6.8                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                      27.0                   NaN
# 1                  NaN                      25.0                   NaN
# 2                  NaN                      14.0                   NaN
# 3                  NaN                      25.0                   NaN
# 4                  NaN                      29.0                   NaN
# ..                 ...                       ...                   ...
# 361                NaN                       NaN                     M
# 362                NaN                      30.0                   NaN
# 363                NaN                       7.0                   NaN
# 364                NaN                       8.0                   NaN
# 365                NaN                       8.0                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                     68.0                   NaN
# 1                     61.0                   NaN
# 2                     55.0                   NaN
# 3                     54.0                   NaN
# 4                     72.0                   NaN
# ..                     ...                   ...
# 361                    NaN                     M
# 362                   39.0                   NaN
# 363                   32.0                   NaN
# 364                   48.0                   NaN
# 365                   33.0                   NaN
#
# [366 rows x 31 columns]

# %%
v2020_df1.isnull().sum()
# Out:
# Longitude (x)                  0
# Latitude (y)                   0
# Station Name                   0
# Climate ID                     0
# Date/Time                      0
# Year                           0
# Month                          0
# Day                            0
# Data Quality                 366
# Max Temp (°C)                  3
# Max Temp Flag                363
# Min Temp (°C)                  3
# Min Temp Flag                363
# Mean Temp (°C)                 3
# Mean Temp Flag               363
# Heat Deg Days (°C)             3
# Heat Deg Days Flag           363
# Cool Deg Days (°C)             3
# Cool Deg Days Flag           363
# Total Rain (mm)                8
# Total Rain Flag              334
# Total Snow (cm)                8
# Total Snow Flag              356
# Total Precip (mm)              0
# Total Precip Flag            341
# Snow on Grnd (cm)            355
# Snow on Grnd Flag            363
# Dir of Max Gust (10s deg)    149
# Dir of Max Gust Flag         239
# Spd of Max Gust (km/h)       149
# Spd of Max Gust Flag         217
# dtype: int64

# %%
#checking for null values
v2020_df1.isna().sum()
# Out:
# Longitude (x)                  0
# Latitude (y)                   0
# Station Name                   0
# Climate ID                     0
# Date/Time                      0
# Year                           0
# Month                          0
# Day                            0
# Data Quality                 366
# Max Temp (°C)                  3
# Max Temp Flag                363
# Min Temp (°C)                  3
# Min Temp Flag                363
# Mean Temp (°C)                 3
# Mean Temp Flag               363
# Heat Deg Days (°C)             3
# Heat Deg Days Flag           363
# Cool Deg Days (°C)             3
# Cool Deg Days Flag           363
# Total Rain (mm)                8
# Total Rain Flag              334
# Total Snow (cm)                8
# Total Snow Flag              356
# Total Precip (mm)              0
# Total Precip Flag            341
# Snow on Grnd (cm)            355
# Snow on Grnd Flag            363
# Dir of Max Gust (10s deg)    149
# Dir of Max Gust Flag         239
# Spd of Max Gust (km/h)       149
# Spd of Max Gust Flag         217
# dtype: int64
