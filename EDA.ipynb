# %%
import pandas as pd

# %%
w2013_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2013_P1H.csv")

# %%
w2013_df1
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time (LST)  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2013-12-01 00:00
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2013-12-01 01:00
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2013-12-01 02:00
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2013-12-01 03:00
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2013-12-01 04:00
# ..             ...           ...            ...        ...               ...
# 739         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31 19:00
# 740         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31 20:00
# 741         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31 21:00
# 742         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31 22:00
# 743         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31 23:00
#
# ...

# %%
w2014_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2014_P1H.csv")

# %%
w2014_df1
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time (LST)  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2014-12-01 00:00
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2014-12-01 01:00
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2014-12-01 02:00
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2014-12-01 03:00
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2014-12-01 04:00
# ..             ...           ...            ...        ...               ...
# 739         -97.25         49.92  WINNIPEG A CS    502S001  2014-12-31 19:00
# 740         -97.25         49.92  WINNIPEG A CS    502S001  2014-12-31 20:00
# 741         -97.25         49.92  WINNIPEG A CS    502S001  2014-12-31 21:00
# 742         -97.25         49.92  WINNIPEG A CS    502S001  2014-12-31 22:00
# 743         -97.25         49.92  WINNIPEG A CS    502S001  2014-12-31 23:00
#
# ...

# %%
w2015_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2015_P1H.csv")

# %%
w2016_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2016_P1H.csv")

# %%
w2017_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2017_P1H.csv")

# %%
w2018_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2018_P1H.csv")

# %%
w2019_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2019_P1H.csv")

# %%
w2020_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2020_P1H.csv")

# %%
w2021_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2021_P1H.csv")

# %%
w2021_df1
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time (LST)  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2021-12-01 00:00
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2021-12-01 01:00
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2021-12-01 02:00
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2021-12-01 03:00
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2021-12-01 04:00
# ..             ...           ...            ...        ...               ...
# 739         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31 19:00
# 740         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31 20:00
# 741         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31 21:00
# 742         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31 22:00
# 743         -97.25         49.92  WINNIPEG A CS    502S001  2021-12-31 23:00
#
# ...

# %%
w2022_df1 = pd.read_csv(r"C:\Users\Tombra\Winnipeg_Weather_Predictions\raw_data_winnipeg_weather\en_climate_hourly_MB_502S001_12-2022_P1H.csv")

# %%
w2022_df1.head(40)
# Out:
#     Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time (LST)  \
# 0          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 00:00
# 1          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 01:00
# 2          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 02:00
# 3          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 03:00
# 4          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 04:00
# 5          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 05:00
# 6          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 06:00
# 7          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 07:00
# 8          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 08:00
# 9          -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 09:00
# 10         -97.25         49.92  WINNIPEG A CS    502S001  2022-12-01 10:00
# ...

# %%
"C:\Users\Tombra\Downloads\en_climate_daily_MB_502S001_2013_P1D.csv"

# %%
Dw2021_df1 = pd.read_csv(r"C:\Users\Tombra\Downloads\en_climate_daily_MB_502S001_2013_P1D.csv")

# %%
Dw2021_df1
# Out:
#      Longitude (x)  Latitude (y)   Station Name Climate ID   Date/Time  Year  \
# 0           -97.25         49.92  WINNIPEG A CS    502S001  2013-01-01  2013
# 1           -97.25         49.92  WINNIPEG A CS    502S001  2013-01-02  2013
# 2           -97.25         49.92  WINNIPEG A CS    502S001  2013-01-03  2013
# 3           -97.25         49.92  WINNIPEG A CS    502S001  2013-01-04  2013
# 4           -97.25         49.92  WINNIPEG A CS    502S001  2013-01-05  2013
# ..             ...           ...            ...        ...         ...   ...
# 360         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-27  2013
# 361         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-28  2013
# 362         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-29  2013
# 363         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-30  2013
# 364         -97.25         49.92  WINNIPEG A CS    502S001  2013-12-31  2013
#
# ...

# %%
DQC2021_df1 = pd.read_csv(r"C:\Users\Tombra\Downloads\en_climate_daily_QC_702S006_2012_P1D.csv")

# %%
DQC2021_df1
# Out:
#      Longitude (x)  Latitude (y)                          Station Name  \
# 0           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 1           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 2           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 3           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 4           -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# ..             ...           ...                                   ...
# 361         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 362         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 363         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 364         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
# 365         -73.74         45.47  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL
#
#     Climate ID   Date/Time  Year  Month  Day  Data Quality  Max Temp (°C)  \
# ...
