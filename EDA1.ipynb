# %%
from Libraries_vancouver_weather import v2013_df1
from Libraries_vancouver_weather import v2014_df1
from Libraries_vancouver_weather import v2015_df1
from Libraries_vancouver_weather import v2016_df1
from Libraries_vancouver_weather import v2017_df1
from Libraries_vancouver_weather import v2018_df1
from Libraries_vancouver_weather import v2019_df1
from Libraries_vancouver_weather import v2020_df1
from Libraries_vancouver_weather import v2021_df1
from Libraries_vancouver_weather import v2022_df1

# %%
import matplotlib.pyplot as plt

# %%
v2013_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2013-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2013-12-31
#
# ...

# %%
column_headers = v2014_df1.columns.tolist()
column_headers
# Out:
# ['Longitude (x)',
#  'Latitude (y)',
#  'Station Name',
#  'Climate ID',
#  'Date/Time',
#  'Year',
#  'Month',
#  'Day',
#  'Data Quality',
#  'Max Temp (°C)',
#  'Max Temp Flag',
#  'Min Temp (°C)',
#  'Min Temp Flag',
#  'Mean Temp (°C)',
#  'Mean Temp Flag',
#  'Heat Deg Days (°C)',
#  'Heat Deg Days Flag',
#  'Cool Deg Days (°C)',
#  'Cool Deg Days Flag',
#  'Total Rain (mm)',
#  'Total Rain Flag',
#  'Total Snow (cm)',
#  'Total Snow Flag',
#  'Total Precip (mm)',
#  'Total Precip Flag',
#  'Snow on Grnd (cm)',
#  'Snow on Grnd Flag',
#  'Dir of Max Gust (10s deg)',
#  'Dir of Max Gust Flag',
#  'Spd of Max Gust (km/h)',
#  'Spd of Max Gust Flag']

# %%
v2015_df1.isna().sum()
# Out:
# Longitude (x)                  0
# Latitude (y)                   0
# Station Name                   0
# Climate ID                     0
# Date/Time                      0
# Year                           0
# Month                          0
# Day                            0
# Data Quality                 365
# Max Temp (°C)                  1
# Max Temp Flag                363
# Min Temp (°C)                  0
# Min Temp Flag                363
# Mean Temp (°C)                 1
# Mean Temp Flag               363
# Heat Deg Days (°C)             1
# Heat Deg Days Flag           363
# Cool Deg Days (°C)             1
# Cool Deg Days Flag           363
# Total Rain (mm)                5
# Total Rain Flag              335
# Total Snow (cm)                2
# Total Snow Flag              362
# Total Precip (mm)              4
# Total Precip Flag            335
# Snow on Grnd (cm)              1
# Snow on Grnd Flag            365
# Dir of Max Gust (10s deg)    156
# ...

# %%
v2013_df1.dtypes
# Out:
# Longitude (x)                float64
# Latitude (y)                 float64
# Station Name                  object
# Climate ID                     int64
# Date/Time                     object
# Year                           int64
# Month                          int64
# Day                            int64
# Data Quality                 float64
# Max Temp (°C)                float64
# Max Temp Flag                 object
# Min Temp (°C)                float64
# Min Temp Flag                 object
# Mean Temp (°C)               float64
# Mean Temp Flag                object
# Heat Deg Days (°C)           float64
# Heat Deg Days Flag            object
# Cool Deg Days (°C)           float64
# Cool Deg Days Flag            object
# Total Rain (mm)              float64
# Total Rain Flag               object
# Total Snow (cm)              float64
# Total Snow Flag               object
# Total Precip (mm)            float64
# Total Precip Flag             object
# ...

# %%
v2014_df1
# Out:
#      Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-01
# 1          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-02
# 2          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-03
# 3          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-04
# 4          -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-05
# ..             ...           ...               ...         ...         ...
# 360        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-27
# 361        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-28
# 362        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-29
# 363        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-30
# 364        -123.18         49.19  VANCOUVER INTL A     1108395  2014-12-31
#
# ...

# %%
v2014_df1.isna().sum()
# Out:
# Longitude (x)                  0
# Latitude (y)                   0
# Station Name                   0
# Climate ID                     0
# Date/Time                      0
# Year                           0
# Month                          0
# Day                            0
# Data Quality                 365
# Max Temp (°C)                  1
# Max Temp Flag                364
# Min Temp (°C)                  0
# Min Temp Flag                364
# Mean Temp (°C)                 1
# Mean Temp Flag               364
# Heat Deg Days (°C)             1
# Heat Deg Days Flag           364
# Cool Deg Days (°C)             1
# Cool Deg Days Flag           364
# Total Rain (mm)                6
# Total Rain Flag              338
# Total Snow (cm)                1
# Total Snow Flag              360
# Total Precip (mm)              6
# Total Precip Flag            336
# Snow on Grnd (cm)             58
# Snow on Grnd Flag            364
# Dir of Max Gust (10s deg)    151
# ...

# %%
selected_columns= [
 'Year',
 'Month',
 'Day','Max Temp (°C)',
 'Min Temp (°C)',
 'Mean Temp (°C)',
 'Heat Deg Days (°C)',
 'Cool Deg Days (°C)',
 'Total Rain (mm)',
 'Total Snow (cm)',
 'Total Precip (mm)',
 'Dir of Max Gust (10s deg)',
 'Spd of Max Gust (km/h)']

v2014_selected= v2014_df1[selected_columns].copy()

# %%
v2014_selected
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0    2014      1    1            6.5            3.0             4.8
# 1    2014      1    2            7.5            5.2             6.4
# 2    2014      1    3            6.8            0.5             3.7
# 3    2014      1    4            4.9           -2.9             1.0
# 4    2014      1    5            4.7           -3.4             0.7
# ..    ...    ...  ...            ...            ...             ...
# 360  2014     12   27            6.5            3.5             5.0
# 361  2014     12   28            4.8           -2.3             1.3
# 362  2014     12   29            5.7           -2.4             1.7
# 363  2014     12   30            1.6           -5.2            -1.8
# 364  2014     12   31            2.1           -5.0            -1.5
#
#      Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# ...

# %%
v2014_selected.isna().sum()
# Out:
# Year                           0
# Month                          0
# Day                            0
# Max Temp (°C)                  1
# Min Temp (°C)                  0
# Mean Temp (°C)                 1
# Heat Deg Days (°C)             1
# Cool Deg Days (°C)             1
# Total Rain (mm)                6
# Total Snow (cm)                1
# Total Precip (mm)              6
# Dir of Max Gust (10s deg)    151
# Spd of Max Gust (km/h)         1
# dtype: int64

# %%
# Find the number of rows in each column that are filled with 0.0
zero_filled_rows_per_column = (v2014_selected == 0.0).sum()

zero_filled_rows_per_column
# Out:
# Year                           0
# Month                          0
# Day                            0
# Max Temp (°C)                  0
# Min Temp (°C)                  2
# Mean Temp (°C)                 0
# Heat Deg Days (°C)            51
# Cool Deg Days (°C)           315
# Total Rain (mm)              204
# Total Snow (cm)              359
# Total Precip (mm)            202
# Dir of Max Gust (10s deg)      0
# Spd of Max Gust (km/h)         0
# dtype: int64

# %%
# fill the NANs in the data frame with 0.0 
v2014_selected_filled = v2014_selected.fillna(0.0)

# %%
v2014_selected_filled
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0    2014      1    1            6.5            3.0             4.8
# 1    2014      1    2            7.5            5.2             6.4
# 2    2014      1    3            6.8            0.5             3.7
# 3    2014      1    4            4.9           -2.9             1.0
# 4    2014      1    5            4.7           -3.4             0.7
# ..    ...    ...  ...            ...            ...             ...
# 360  2014     12   27            6.5            3.5             5.0
# 361  2014     12   28            4.8           -2.3             1.3
# 362  2014     12   29            5.7           -2.4             1.7
# 363  2014     12   30            1.6           -5.2            -1.8
# 364  2014     12   31            2.1           -5.0            -1.5
#
#      Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# ...

# %%
#checking for nans
v2014_selected_filled.isna().sum()
# Out:
# Year                         0
# Month                        0
# Day                          0
# Max Temp (°C)                0
# Min Temp (°C)                0
# Mean Temp (°C)               0
# Heat Deg Days (°C)           0
# Cool Deg Days (°C)           0
# Total Rain (mm)              0
# Total Snow (cm)              0
# Total Precip (mm)            0
# Dir of Max Gust (10s deg)    0
# Spd of Max Gust (km/h)       0
# dtype: int64

# %%
v2014_selected_filled.describe()
# Out:
#          Year       Month         Day  Max Temp (°C)  Min Temp (°C)  \
# count   365.0  365.000000  365.000000     365.000000     365.000000
# mean   2014.0    6.526027   15.720548      14.400822       7.549041
# std       0.0    3.452584    8.808321       6.695035       5.976895
# min    2014.0    1.000000    1.000000      -0.100000      -9.900000
# 25%    2014.0    4.000000    8.000000       8.900000       3.300000
# 50%    2014.0    7.000000   16.000000      14.200000       8.600000
# 75%    2014.0   10.000000   23.000000      20.100000      12.600000
# max    2014.0   12.000000   31.000000      28.300000      18.500000
#
#        Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# count      365.000000          365.000000          365.000000
# mean        10.982740            7.183836            0.215890
# std          6.212722            5.903094            0.665202
# min         -4.500000            0.000000            0.000000
# ...

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.scatter(v2014_selected['Day'], v2014_selected['Max Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Day and Max Temp')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected['Day'], v2014_selected['Max Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Day and Max Temp')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected_filled['Day'], v2014_selected_filled['Max Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Day and Max Temp')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected['Month'], v2014_selected['Max Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Month')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Month and Max Temp')
plt.grid(True)
plt.show()

# %%
#plot the relationship between temperature and month

plt.figure(figsize=(10, 6))  # Set the figure size
plt.scatter(v2014_selected['Day'], v2014_selected['Min Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Month')
plt.ylabel('Min Temp (°C)')
plt.title('Relationship between Month and Min Temp')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected['Month'], v2014_selected['Min Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Month')
plt.ylabel('Min Temp (°C)')
plt.title('Relationship between Month and Min Temp')
plt.grid(True)
plt.show()

# %%
v2014_selected
# Out:
#      Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0    2014      1    1            6.5            3.0             4.8
# 1    2014      1    2            7.5            5.2             6.4
# 2    2014      1    3            6.8            0.5             3.7
# 3    2014      1    4            4.9           -2.9             1.0
# 4    2014      1    5            4.7           -3.4             0.7
# ..    ...    ...  ...            ...            ...             ...
# 360  2014     12   27            6.5            3.5             5.0
# 361  2014     12   28            4.8           -2.3             1.3
# 362  2014     12   29            5.7           -2.4             1.7
# 363  2014     12   30            1.6           -5.2            -1.8
# 364  2014     12   31            2.1           -5.0            -1.5
#
#      Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# ...

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected_filled['Month'], v2014_selected_filled['Total Precip (mm)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Month and Total Precip')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2014_selected['Month'], v2014_selected['Total Precip (mm)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Month and Total Precip')
plt.grid(True)
plt.show()
