# %%
from Libraries_vancouver_weather import v2013_df1
from Libraries_vancouver_weather import v2014_df1
from Libraries_vancouver_weather import v2015_df1
from Libraries_vancouver_weather import v2016_df1
from Libraries_vancouver_weather import v2017_df1
from Libraries_vancouver_weather import v2018_df1
from Libraries_vancouver_weather import v2019_df1
from Libraries_vancouver_weather import v2020_df1
from Libraries_vancouver_weather import v2021_df1
from Libraries_vancouver_weather import v2022_df1

# %%
#import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_white"

# %%
#combining all the dataframes from 2014 to 2022 into one dataframe


# List of DataFrame variables
dataframes = [ v2014_df1, v2015_df1, v2016_df1, v2017_df1, v2018_df1, v2019_df1, v2020_df1, v2021_df1, v2022_df1]

# Concatenate DataFrames vertically
combined_df = pd.concat(dataframes, ignore_index=True)

#  combined_df holds the concatenated data from all DataFrames

# %%
print(len(dataframes))
# Out:
# 9

# %%
print (len(v2014_df1))
# Out:
# 365

# %%
print (len(combined_df))
# Out:
# 3287

# %%
#display the concatenated dataframe
combined_df
# Out:
#       Longitude (x)  Latitude (y)      Station Name  Climate ID   Date/Time  \
# 0           -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-01
# 1           -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-02
# 2           -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-03
# 3           -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-04
# 4           -123.18         49.19  VANCOUVER INTL A     1108395  2014-01-05
# ...             ...           ...               ...         ...         ...
# 3282        -123.18         49.19  VANCOUVER INTL A     1108395  2022-12-27
# 3283        -123.18         49.19  VANCOUVER INTL A     1108395  2022-12-28
# 3284        -123.18         49.19  VANCOUVER INTL A     1108395  2022-12-29
# 3285        -123.18         49.19  VANCOUVER INTL A     1108395  2022-12-30
# 3286        -123.18         49.19  VANCOUVER INTL A     1108395  2022-12-31
#
# ...

# %%
#list the column headers in the dataframe
column_headers = combined_df.columns.tolist()
column_headers
# Out:
# ['Longitude (x)',
#  'Latitude (y)',
#  'Station Name',
#  'Climate ID',
#  'Date/Time',
#  'Year',
#  'Month',
#  'Day',
#  'Data Quality',
#  'Max Temp (°C)',
#  'Max Temp Flag',
#  'Min Temp (°C)',
#  'Min Temp Flag',
#  'Mean Temp (°C)',
#  'Mean Temp Flag',
#  'Heat Deg Days (°C)',
#  'Heat Deg Days Flag',
#  'Cool Deg Days (°C)',
#  'Cool Deg Days Flag',
#  'Total Rain (mm)',
#  'Total Rain Flag',
#  'Total Snow (cm)',
#  'Total Snow Flag',
#  'Total Precip (mm)',
#  'Total Precip Flag',
#  'Snow on Grnd (cm)',
#  'Snow on Grnd Flag',
#  'Dir of Max Gust (10s deg)',
#  'Dir of Max Gust Flag',
#  'Spd of Max Gust (km/h)',
#  'Spd of Max Gust Flag']

# %%
#check for nans in the dataframe
combined_df.isna().sum()
# Out:
# Longitude (x)                   0
# Latitude (y)                    0
# Station Name                    0
# Climate ID                      0
# Date/Time                       0
# Year                            0
# Month                           0
# Day                             0
# Data Quality                 3287
# Max Temp (°C)                  23
# Max Temp Flag                3258
# Min Temp (°C)                  17
# Min Temp Flag                3258
# Mean Temp (°C)                 25
# Mean Temp Flag               3258
# Heat Deg Days (°C)             25
# Heat Deg Days Flag           3258
# Cool Deg Days (°C)             25
# Cool Deg Days Flag           3258
# Total Rain (mm)                33
# Total Rain Flag              3042
# Total Snow (cm)                19
# Total Snow Flag              3237
# Total Precip (mm)              21
# Total Precip Flag            3034
# Snow on Grnd (cm)            2146
# Snow on Grnd Flag            3063
# ...

# %%
#check the data types in the dataframe
combined_df.dtypes
# Out:
# Longitude (x)                float64
# Latitude (y)                 float64
# Station Name                  object
# Climate ID                     int64
# Date/Time                     object
# Year                           int64
# Month                          int64
# Day                            int64
# Data Quality                 float64
# Max Temp (°C)                float64
# Max Temp Flag                 object
# Min Temp (°C)                float64
# Min Temp Flag                 object
# Mean Temp (°C)               float64
# Mean Temp Flag                object
# Heat Deg Days (°C)           float64
# Heat Deg Days Flag            object
# Cool Deg Days (°C)           float64
# Cool Deg Days Flag            object
# Total Rain (mm)              float64
# Total Rain Flag               object
# Total Snow (cm)              float64
# Total Snow Flag               object
# Total Precip (mm)            float64
# Total Precip Flag             object
# ...

# %%
#select important columns from the dataframe "combined" into another dataframe
selected_columns= [
 'Year',
 'Month',
 'Day','Max Temp (°C)',
 'Min Temp (°C)',
 'Mean Temp (°C)',
 'Heat Deg Days (°C)',
 'Cool Deg Days (°C)',
 'Total Rain (mm)',
 'Total Snow (cm)',
 'Total Precip (mm)',
 'Dir of Max Gust (10s deg)',
 'Spd of Max Gust (km/h)']

combined_selected= combined_df[selected_columns].copy()

# %%
#view the new dataframe with the selected columns
combined_selected
# Out:
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     2014      1    1            6.5            3.0             4.8
# 1     2014      1    2            7.5            5.2             6.4
# 2     2014      1    3            6.8            0.5             3.7
# 3     2014      1    4            4.9           -2.9             1.0
# 4     2014      1    5            4.7           -3.4             0.7
# ...    ...    ...  ...            ...            ...             ...
# 3282  2022     12   27            9.8            6.4             8.1
# 3283  2022     12   28            8.1            3.5             5.8
# 3284  2022     12   29            6.5            3.2             4.9
# 3285  2022     12   30           10.4            5.2             7.8
# 3286  2022     12   31            9.6            2.2             5.9
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0                   13.2                 0.0              0.8
# ...

# %%
#check for nans
combined_selected.isna().sum()
# Out:
# Year                            0
# Month                           0
# Day                             0
# Max Temp (°C)                  23
# Min Temp (°C)                  17
# Mean Temp (°C)                 25
# Heat Deg Days (°C)             25
# Cool Deg Days (°C)             25
# Total Rain (mm)                33
# Total Snow (cm)                19
# Total Precip (mm)              21
# Dir of Max Gust (10s deg)    1284
# Spd of Max Gust (km/h)        643
# dtype: int64

# %%
# Find the number of rows in each column that are filled with 0.0
zero_filled_rows_per_column = (combined_selected == 0.0).sum()

zero_filled_rows_per_column
# Out:
# Year                            0
# Month                           0
# Day                             0
# Max Temp (°C)                   1
# Min Temp (°C)                  13
# Mean Temp (°C)                  4
# Heat Deg Days (°C)            445
# Cool Deg Days (°C)           2829
# Total Rain (mm)              1822
# Total Snow (cm)              3200
# Total Precip (mm)            1798
# Dir of Max Gust (10s deg)       0
# Spd of Max Gust (km/h)          0
# dtype: int64

# %%
# fill the NANs in the data frame with 0.0 
combined_selected_filled = combined_selected.fillna(0.0)

# %%
# Find the number of rows in each column that are filled with 0.0 after converting nans to 0.0
zero_filled_rows_per_column_2 = (combined_selected_filled == 0.0).sum()

zero_filled_rows_per_column_2
# Out:
# Year                            0
# Month                           0
# Day                             0
# Max Temp (°C)                  24
# Min Temp (°C)                  30
# Mean Temp (°C)                 29
# Heat Deg Days (°C)            470
# Cool Deg Days (°C)           2854
# Total Rain (mm)              1855
# Total Snow (cm)              3219
# Total Precip (mm)            1819
# Dir of Max Gust (10s deg)    1284
# Spd of Max Gust (km/h)        643
# dtype: int64

# %%
#view the dataframe
combined_selected_filled
# Out:
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     2014      1    1            6.5            3.0             4.8
# 1     2014      1    2            7.5            5.2             6.4
# 2     2014      1    3            6.8            0.5             3.7
# 3     2014      1    4            4.9           -2.9             1.0
# 4     2014      1    5            4.7           -3.4             0.7
# ...    ...    ...  ...            ...            ...             ...
# 3282  2022     12   27            9.8            6.4             8.1
# 3283  2022     12   28            8.1            3.5             5.8
# 3284  2022     12   29            6.5            3.2             4.9
# 3285  2022     12   30           10.4            5.2             7.8
# 3286  2022     12   31            9.6            2.2             5.9
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0                   13.2                 0.0              0.8
# ...

# %%
#checking for nans
combined_selected_filled.isna().sum()
# Out:
# Year                         0
# Month                        0
# Day                          0
# Max Temp (°C)                0
# Min Temp (°C)                0
# Mean Temp (°C)               0
# Heat Deg Days (°C)           0
# Cool Deg Days (°C)           0
# Total Rain (mm)              0
# Total Snow (cm)              0
# Total Precip (mm)            0
# Dir of Max Gust (10s deg)    0
# Spd of Max Gust (km/h)       0
# dtype: int64

# %%
#describe the df
combined_selected_filled.describe()
# Out:
#               Year        Month          Day  Max Temp (°C)  Min Temp (°C)  \
# count  3287.000000  3287.000000  3287.000000    3287.000000    3287.000000
# mean   2018.000000     6.523274    15.728628      14.136964       7.103316
# std       2.582067     3.449133     8.801004       6.722375       5.819272
# min    2014.000000     1.000000     1.000000      -7.800000     -15.300000
# 25%    2016.000000     4.000000     8.000000       8.800000       2.900000
# 50%    2018.000000     7.000000    16.000000      13.800000       7.200000
# 75%    2020.000000    10.000000    23.000000      19.800000      12.000000
# max    2022.000000    12.000000    31.000000      32.400000      20.400000
#
#        Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# count     3287.000000         3287.000000         3287.000000
# mean        10.629145            7.458382            0.224430
# std          6.134773            5.766098            0.757508
# ...

# %%
#plot the relationship between day and temperature
plt.figure(figsize=(10, 6))  # Set the figure size
plt.scatter(combined_selected_filled['Day'], combined_selected_filled['Max Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Day and Max Temp')
plt.grid(True)
plt.show()

# %%
#plot bar chart to view relationship 
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Day'], combined_selected_filled['Max Temp (°C)'], alpha=0.5)  # Create a bar chart
plt.xlabel('Day')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Day and Max Temp')
plt.grid(True)
plt.show()

# %% [markdown]
# Throughout the various days of the month maximum temperatures ranged between 0 and 25 degrees on an average

# %%
# To calculate total snowfall for each month
monthly_total_snow = combined_selected_filled.groupby('Month')['Total Snow (cm)'].sum()

# %%
#link the monthly total snow to each month based on cm from the total snow
monthly_total_snow = monthly_total_snow.reset_index(name='Total Snow (cm)')

# %%
#plot a pie chart to visualize the month with mos snow
pie_chart=px.pie(monthly_total_snow, values='Total Snow (cm)', names = 'Month',title = 'Snowfall by month',hover_data=['Total Snow (cm)'],hole =0)
pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()

# %% [markdown]
# over the years month 2(february) has the highest amount of snowfall

# %%
# To calculate total snowfall for each year
yearly_total_snow = combined_selected_filled.groupby('Year')['Total Snow (cm)'].sum()

# %%
#link the yearly total snow to each year based on cm from the total snow
yearly_total_snow = yearly_total_snow.reset_index(name='Total Snow (cm)')

# %%
#plot a pie chart to visualize the month with mos snow
pie_chart=px.pie(yearly_total_snow, values='Total Snow (cm)', names = 'Year',title = 'Snowfall by Year',hover_data=['Total Snow (cm)'],hole =0)
pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()

# %% [markdown]
# over the sample period, the year 2022 had the highest amount of snowfall

# %%
#Relationship between Month and Max Temp

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Month'], combined_selected_filled['Max Temp (°C)'], alpha=0.5)  # Create a bar chart
plt.xlabel('Month')
plt.ylabel('Max Temp (°C)')
plt.title('Relationship between Month and Max Temp')
plt.grid(True)
plt.show()

# %%
#plot the relationship between temperature and month

plt.figure(figsize=(10, 6))  # Set the figure size
plt.scatter(combined_selected_filled['Day'], combined_selected_filled['Min Temp (°C)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Month')
plt.ylabel('Min Temp (°C)')
plt.title('Relationship between Month and Min Temp')
plt.grid(True)
plt.show()

# %%
#plot relationship between month and minimum temperature

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(v2016_df1['Month'], v2016_df1['Min Temp (°C)'], alpha=0.5)  # Create a bar chart
plt.xlabel('Month')
plt.ylabel('Min Temp (°C)')
plt.title('Relationship between Month and Min Temp')
plt.grid(True)
plt.show()

# %%
#Relationship between Month and Min Temp

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Month'], combined_selected_filled['Min Temp (°C)'], alpha=0.5)  # Create a bar chart
plt.xlabel('Month')
plt.ylabel('Min Temp (°C)')
plt.title('Relationship between Month and Min Temp')
plt.grid(True)
plt.show()

# %%
#Relationship between Month and Total Precip

plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Month'], combined_selected_filled['Total Precip (mm)'], alpha=1)  # Create a bar chart
plt.xlabel('Month')
plt.ylabel('Total Precip (mm)')
plt.title('Relationship between Month and Total Snowfall')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Day'], combined_selected_filled['Total Precip (mm)'], alpha=0.5)  # Create a scatter plot
plt.xlabel('Day')
plt.ylabel('Total Precip (mm)')
plt.title('Relationship between Day and Total Precip')
plt.grid(True)
plt.show()

# %%
combined_selected_filled
# Out:
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     2014      1    1            6.5            3.0             4.8
# 1     2014      1    2            7.5            5.2             6.4
# 2     2014      1    3            6.8            0.5             3.7
# 3     2014      1    4            4.9           -2.9             1.0
# 4     2014      1    5            4.7           -3.4             0.7
# ...    ...    ...  ...            ...            ...             ...
# 3282  2022     12   27            9.8            6.4             8.1
# 3283  2022     12   28            8.1            3.5             5.8
# 3284  2022     12   29            6.5            3.2             4.9
# 3285  2022     12   30           10.4            5.2             7.8
# 3286  2022     12   31            9.6            2.2             5.9
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0                   13.2                 0.0              0.8
# ...

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
plt.bar(combined_selected_filled['Day'], combined_selected_filled['Total Rain (mm)'], alpha=0.5)  # Create a bar chart
plt.xlabel('Day')
plt.ylabel('Total Rain (mm)')
plt.title('Relationship between Day and Total Rain')
plt.grid(True)
plt.show()

# %%
# Calculate total daily precipitation for each month
monthly_total_precipitation = combined_selected_filled.groupby('Month')['Total Rain (mm)'].sum()

# Create a bar plot to show the total precipitation for each month
plt.figure(figsize=(10, 6))
monthly_total_precipitation.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Total Precipitation (mm)')
plt.title('Total Precipitation for Each Month')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_precipitation_month = monthly_total_precipitation.idxmax()
print(f"The month with the highest total precipitation is {max_precipitation_month}.")
# Out:
# The month with the highest total precipitation is 11.

# %% [markdown]
# Here the 11 month refers to the month of November and precipitation is inclusive of snow and rainfall

# %%
monthly_total_precipitation = monthly_total_precipitation.reset_index(name='Total Rain (mm)')

# %%
pie_chart=px.pie(monthly_total_precipitation, values='Total Rain (mm)', names = 'Month',title = 'Precipitation by month',hover_data=['Total Rain (mm)'],hole =0)
pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()

# %%
# Calculate total daily rainfall for each month
Daily_total_rainfall = combined_selected_filled.groupby('Day')['Total Rain (mm)'].sum()

# Create a bar plot to show the total precipitation for each month
plt.figure(figsize=(10, 6))
Daily_total_rainfall.plot(kind='bar')
plt.xlabel('Day')
plt.ylabel('Total Rain (mm)')
plt.title('Total Rainfal according to the Day')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_precipitation_Day = Daily_total_rainfall.idxmax()
print(f"The day with the highest total rainfall is {max_precipitation_Day}.")
# Out:
# The day with the highest total rainfall is 12.

# %% [markdown]
# From the dataset the 12th day of the month is observed to have the highest sum total rainfall within the study time frame

# %%
Daily_total_rainfall = Daily_total_rainfall.reset_index(name='Total Rain (mm)')

# %%
#piechart representation of the total rainfall by days (the day that has the most rainfall)
pie_chart=px.pie(Daily_total_rainfall, values='Total Rain (mm)', names = 'Day',title = 'total rainfall by day',hover_data=['Total Rain (mm)'],hole =0)
pie_chart.update_traces(textposition='inside', textinfo='percent+label')
pie_chart.show()

# %% [markdown]
# The 12th day is seen to have the most rainfall within the dataset

# %%
combined_selected_filled
# Out:
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     2014      1    1            6.5            3.0             4.8
# 1     2014      1    2            7.5            5.2             6.4
# 2     2014      1    3            6.8            0.5             3.7
# 3     2014      1    4            4.9           -2.9             1.0
# 4     2014      1    5            4.7           -3.4             0.7
# ...    ...    ...  ...            ...            ...             ...
# 3282  2022     12   27            9.8            6.4             8.1
# 3283  2022     12   28            8.1            3.5             5.8
# 3284  2022     12   29            6.5            3.2             4.9
# 3285  2022     12   30           10.4            5.2             7.8
# 3286  2022     12   31            9.6            2.2             5.9
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0                   13.2                 0.0              0.8
# ...

# %%
# Calculate total daily mean temp for each month
Daily_total_mean_Days = combined_selected_filled.groupby('Month')['Mean Temp (°C)'].sum()

# Create a bar plot to show the total mean temp for each month
plt.figure(figsize=(10, 6))
Daily_total_mean_Days.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Mean Temp (°C)')
plt.title('Mean Temp (°C) according to the Month')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_mean_Days.idxmax()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
# Out:
# The month with the highest total heat days is 7.

# %%
# Calculate total daily mean temp for each month
Daily_total_mean_Days  = combined_selected_filled.groupby('Month')['Mean Temp (°C)'].sum()

Daily_total_mean_Days_adjusted = Daily_total_mean_Days/100

# Convert the mean temperature from Celsius to Fahrenheit
Daily_total_mean_Days_fahrenheit = (Daily_total_mean_Days_adjusted * 9/5) + 32

# Create a line plot to show the total mean temp for each month in Fahrenheit
plt.figure(figsize=(10, 6))
Daily_total_mean_Days_fahrenheit.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Mean Temp (°F)')
plt.title('Mean Temp (°F) according to the Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_mean_Days_fahrenheit.idxmax()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
# Out:
# The month with the highest total heat days is 7.

# %%
# Calculate total daily mean temp for each month
Daily_total_mean_Days = combined_selected_filled.groupby('Month')['Mean Temp (°C)'].sum()

# Create a bar plot to show the total mean temp for each month
plt.figure(figsize=(10, 6))
Daily_total_mean_Days.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Mean Temp (°C)')
plt.title('Mean Temp (°C) according to the Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_mean_Days.idxmax()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
# Out:
# The month with the highest total heat days is 7.

# %%
# Adjust the temperature values by dividing by 100
Daily_total_mean_Days_adjusted = Daily_total_mean_Days / 100

# Create a bar plot to show the total mean temp for each month
plt.figure(figsize=(10, 6))
Daily_total_mean_Days_adjusted.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Mean Temp (°C)')
plt.title('Mean Temp (°C) according to the Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_mean_Days_adjusted.idxmax()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
# Out:
# The month with the highest total heat days is 7.

# %%
# Calculate total daily mean temp for each month
Daily_total_mean_Days = combined_selected_filled.groupby('Month')['Mean Temp (°C)'].sum()

# Scale down the temperature values by dividing by 100
Daily_total_mean_Days_scaled = Daily_total_mean_Days / 100

# Create a bar plot to show the total mean temp for each month with scaled values
plt.figure(figsize=(10, 6))
Daily_total_mean_Days_scaled.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Mean Temp (°C) (Scaled)')
plt.title('Mean Temp (°C) according to the Month (Scaled)')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_mean_Days_scaled.idxmax()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
# Out:
# The month with the highest total heat days is 7.

# %%
# Calculate the total daily max temperature for each month
Monthly_total_max_temp = combined_selected_filled.groupby('Month')['Max Temp (°C)'].max()

# Identify the maximum temperature and the month
max_temp = Monthly_total_max_temp.max()
max_temp_month = Monthly_total_max_temp.idxmax()

print(f"The maximum temperature is {max_temp}°C, and it occurred in the month {max_temp_month}.")
# Out:
# The maximum temperature is 32.4°C, and it occurred in the month 6.

# %%
# Calculate total daily heat for each month
Daily_total_Heat_Days = combined_selected_filled.groupby('Month')['Max Temp (°C)'].sum()

# Create a bar plot to show the total heat for each month
plt.figure(figsize=(10, 6))
Daily_total_Heat_Days.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Max Temp (°C)')
plt.title('Max Temp (°C) according to the Month')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_Heat_Month = Daily_total_Heat_Days.idxmax()
Max_temp = Daily_total_Heat_Days.max()
print(f"The month with the highest total heat days is {max_Heat_Month}.")
print(Max_temp)
# Out:
# The month with the highest total heat days is 7.
# 6376.1

# %%
# Calculate total daily heat for each month
Daily_Total_Snow = combined_selected_filled.groupby('Month')['Total Snow (cm)'].sum()

# Create a bar plot to show the total heat for each month
plt.figure(figsize=(10, 6))
Daily_Total_Snow .plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Total Snow (cm)')
plt.title('Total Snow (cm) according to the Month')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Identify the month with the highest total precipitation
max_snow_Month =Daily_Total_Snow .idxmax()
print(f"The month with the highest total snow days is {max_snow_Month}.")
# Out:
# The month with the highest total snow days is 2.

# %%
# Filter the DataFrame for days where temperature is greater than 28 degrees
heat_days = combined_selected_filled[(combined_selected_filled['Heat Deg Days (°C)'] > 28)]

# Count the total number of heat days
total_heat_days = heat_days.shape[0]

print(f"The total number of heat days where temperature is greater than 28 degrees is: {total_heat_days}")
# Out:
# The total number of heat days where temperature is greater than 28 degrees is: 2

# %%
#to calculate the number of hot days greater than 20 degrees

# Filter the DataFrame for heat days where temperature is greater than 28 degrees
heat_days = combined_selected_filled[(combined_selected_filled['Heat Deg Days (°C)'] > 18)]

# Count the total number of heat days
total_heat_days = heat_days.shape[0]

print(f"The total number of heat days where temperature is greater than 20 degrees is: {total_heat_days}")
# Out:
# The total number of heat days where temperature is greater than 20 degrees is: 114

# %%
#to calculate the number of hot days greater than 20 degrees

# Filter the DataFrame for heat days where temperature is greater than 18 degrees
heat_days = combined_selected_filled[(combined_selected_filled['Heat Deg Days (°C)'] < 18)]

# Count the total number of heat days
total_heat_days = heat_days.shape[0]

print(f"The total number of heat days where temperature is less than 18 degrees is: {total_heat_days}")
# Out:
# The total number of heat days where temperature is less than 18 degrees is: 3169

# %%
combined_selected_filled
# Out:
#       Year  Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0     2014      1    1            6.5            3.0             4.8
# 1     2014      1    2            7.5            5.2             6.4
# 2     2014      1    3            6.8            0.5             3.7
# 3     2014      1    4            4.9           -2.9             1.0
# 4     2014      1    5            4.7           -3.4             0.7
# ...    ...    ...  ...            ...            ...             ...
# 3282  2022     12   27            9.8            6.4             8.1
# 3283  2022     12   28            8.1            3.5             5.8
# 3284  2022     12   29            6.5            3.2             4.9
# 3285  2022     12   30           10.4            5.2             7.8
# 3286  2022     12   31            9.6            2.2             5.9
#
#       Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  \
# 0                   13.2                 0.0              0.8
# ...

# %%
combined_selected_filled.describe()
# Out:
#               Year        Month          Day  Max Temp (°C)  Min Temp (°C)  \
# count  3287.000000  3287.000000  3287.000000    3287.000000    3287.000000
# mean   2018.000000     6.523274    15.728628      14.136964       7.103316
# std       2.582067     3.449133     8.801004       6.722375       5.819272
# min    2014.000000     1.000000     1.000000      -7.800000     -15.300000
# 25%    2016.000000     4.000000     8.000000       8.800000       2.900000
# 50%    2018.000000     7.000000    16.000000      13.800000       7.200000
# 75%    2020.000000    10.000000    23.000000      19.800000      12.000000
# max    2022.000000    12.000000    31.000000      32.400000      20.400000
#
#        Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# count     3287.000000         3287.000000         3287.000000
# mean        10.629145            7.458382            0.224430
# std          6.134773            5.766098            0.757508
# ...

# %%
#to calculate the number of hot days greater than 22 degrees

# Filter the DataFrame for heat days where temperature is greater than 22 degrees
heat_days = combined_selected_filled[(combined_selected_filled['Heat Deg Days (°C)'] > 22 )]

# Count the total number of heat days
total_heat_days = heat_days.shape[0]

print(f"The total number of heat days where temperature is greater than 22 degrees is: {total_heat_days}")
# Out:
# The total number of heat days where temperature is greater than 22 degrees is: 20

# %%
#to calculate the number of days with total snow greater than 5cm

# Filter the DataFrame for where total snow is greater than 5cm
snow_volume = combined_selected_filled[(combined_selected_filled['Total Snow (cm)'] > 5)]

# Count the total number of snow volume
total_snow_volume = snow_volume.shape[0]

print(f"The total_snow_volume where snow is greater than 5cm is: {total_snow_volume}")
# Out:
# The total_snow_volume where snow is greater than 5cm is: 23

# %%
#to calculate the number of hot days greater than 20 degrees

# Filter the DataFrame for heat days where temperature is greater than 20 degrees
mean_temperature = combined_selected_filled[(combined_selected_filled['Mean Temp (°C)'] > 20)]

# Count the total number of heat days
total_mean_temp_days = mean_temperature.shape[0]

print(f"The total days where mean temp is greater than 20 is: {total_mean_temp_days}")
# Out:
# The total days where mean temp is greater than 20 is: 144

# %%
combined_selected_filled.isnull().sum()
# Out:
# Year                         0
# Month                        0
# Day                          0
# Max Temp (°C)                0
# Min Temp (°C)                0
# Mean Temp (°C)               0
# Heat Deg Days (°C)           0
# Cool Deg Days (°C)           0
# Total Rain (mm)              0
# Total Snow (cm)              0
# Total Precip (mm)            0
# Dir of Max Gust (10s deg)    0
# Spd of Max Gust (km/h)       0
# dtype: int64

# %%
# Save to CSV
combined_selected_filled.to_csv(r'C:\Users\Tombra\Vancouver_Weather_Predictions\combined_selected_filled.csv', index=False)
